# %% [markdown]
# ### **addition**

# %%
import numpy as np

a=np.array([10,20,30])
b=np.array([1,2,3])
a+b
# Out:
# array([11, 22, 33])

# %% [markdown]
# **subtraction**

# %%
import numpy as np
a=np.array([40,50,60])
b=np.array([16,17,20])
a-b
# Out:
# array([24, 33, 40])

# %% [markdown]
# **multipliction**

# %%
import numpy as np
a=np.array([50,60,70])
b=np.array([10,20,30])
a*b
# Out:
# array([ 500, 1200, 2100])
