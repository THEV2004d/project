# 41      O42       C3611  2025-03-28      23:49       Salem     T Nagar
# 42      O43       C3215  2025-08-05      21:40     Chennai    Tambaram
# 43      O44       C3015  2025-03-18      12:45      Trichy  Anna Nagar
# 44      O45       C3675  2025-04-07      22:14      Trichy  Anna Nagar
# 45      O46       C8264  2025-07-08      09:17     Madurai   Velachery
# 46      O47       C8910  2025-03-31      15:29       Salem       Porur
# 47      O48       C8344  2025-12-10      16:01       Salem    Tambaram
# 48      O49       C5113  2025-10-14      08:21      Trichy     T Nagar
# 49      O50       C3726  2025-03-28      15:46  Coimbatore   Velachery
#
#       Restaurant   Food_Item Category  Quantity  Price  Delivery_Time_Min  \
# 0    Burger King        Dosa      Veg         4    325                 38
# 1            KFC  Fried Rice  Non-Veg         5    232                 18
# 2   SS Hyderabad     Parotta  Non-Veg         3    286                 33
# 3    Burger King    Sandwich      Veg         2    491                 46
# 4        Dominos    Sandwich      Veg         4    321                 26
# 5            A2B       Meals      Veg         4    122                 30
# 6            A2B     Noodles  Non-Veg         4    378                 49
# 7            KFC  Fried Rice  Non-Veg         5    101                 49
# 8        Dominos    Sandwich  Non-Veg         4    158                 60
# 9        Dominos        Dosa      Veg         3    156                 34
# 10  SS Hyderabad        Dosa  Non-Veg         3    220                 16
# 11   Burger King     Biryani  Non-Veg         5    306                 34
# 12   Burger King  Fried Rice      Veg         5    330                 54
# 13   Burger King     Noodles  Non-Veg         5    276                 34
# 14   Burger King        Dosa      Veg         1    420                 40
# 15       Dominos  Fried Rice  Non-Veg         4    428                 60
# 16           KFC       Pizza  Non-Veg         4    122                 40
# 17           A2B     Biryani      Veg         2    381                 57
# 18   Burger King     Noodles      Veg         1    194                 39
# 19           KFC    Sandwich      Veg         2    395                 35
# 20  SS Hyderabad  Chicken 65      Veg         1    112                 19
# 21   Burger King     Parotta      Veg         4    429                 41
# 22  SS Hyderabad  Fried Rice      Veg         3    332                 35
# 23   Burger King     Noodles      Veg         1    479                 36
# 24   Burger King      Burger      Veg         5    219                 31
# 25           A2B     Biryani      Veg         1    336                 20
# 26           KFC      Burger      Veg         1    434                 20
# 27  SS Hyderabad     Biryani  Non-Veg         4    340                 26
# 28  SS Hyderabad        Dosa  Non-Veg         1    346                 50
# 29   Burger King     Noodles      Veg         1    231                 21
# 30           KFC        Dosa      Veg         3    411                 35
# 31           KFC  Chicken 65  Non-Veg         3    348                 45
# 32           A2B       Pizza      Veg         3    436                 51
# 33   Burger King       Pizza      Veg         5    109                 46
# 34  SS Hyderabad  Chicken 65      Veg         3    261                 57
# 35  SS Hyderabad  Chicken 65      Veg         4    464                 30
# 36  SS Hyderabad     Parotta      Veg         4    168                 33
# 37       Dominos      Burger  Non-Veg         2    417                 18
# 38           A2B    Sandwich      Veg         5    340                 30
# 39  SS Hyderabad    Sandwich  Non-Veg         1    245                 58
# 40           A2B      Burger      Veg         5    362                 26
# 41           KFC      Burger  Non-Veg         1    431                 41
# 42  SS Hyderabad       Pizza  Non-Veg         3     96                 46
# 43       Dominos     Biryani  Non-Veg         3    307                 34
# 44           KFC        Dosa      Veg         2    394                 54
# 45           KFC    Sandwich      Veg         4    197                 26
# 46       Dominos  Chicken 65      Veg         3    344                 54
# 47           A2B  Chicken 65  Non-Veg         3    264                 57
# 48           A2B     Biryani      Veg         5    225                 21
# 49   Burger King     Noodles  Non-Veg         1     89                 40
#
#    Payment_Mode  Rating
# 0          Card     5.0
# 1           UPI     3.5
# 2          Cash     4.7
# 3          Cash     3.0
# 4          Cash     4.4
# 5          Cash     4.0
# 6          Card     4.1
# 7          Card     3.9
# 8           UPI     3.9
# 9           UPI     4.1
# 10         Cash     4.8
# 11         Cash     5.0
# 12         Cash     4.5
# 13         Cash     4.0
# 14         Card     3.2
# 15          UPI     3.4
# 16          UPI     3.1
# 17         Cash     3.0
# 18         Card     3.9
# 19          UPI     3.9
# 20         Card     4.1
# 21         Card     4.8
# 22         Cash     3.1
# 23          UPI     4.5
# 24          UPI     3.4
# 25         Card     3.2
# 26         Cash     4.6
# 27          UPI     3.5
# 28          UPI     3.0
# 29          UPI     3.1
# 30         Cash     3.8
# 31         Cash     3.3
# 32         Card     3.6
# 33         Cash     3.7
# 34         Card     4.6
# 35         Cash     3.6
# 36         Card     4.1
# 37          UPI     4.4
# 38         Card     3.7
# 39         Card     4.8
# 40          UPI     3.4
# 41          UPI     4.7
# 42         Card     3.4
# 43         Cash     3.9
# 44          UPI     3.8
# 45          UPI     4.3
# 46         Card     4.5
# 47          UPI     3.3
# 48          UPI     3.5
# 49         Cash     3.4

# %%
df.tail(8)
# Out:
#      Order_ID Customer_ID  Order_Date Order_Time        City        Area  \
# 4992    O4993       C7542  2025-03-14      14:23      Trichy   Velachery
# 4993    O4994       C7847  2025-01-19      22:24  Coimbatore   Velachery
# 4994    O4995       C8454  2025-08-19      03:11      Trichy   Velachery
# 4995    O4996       C8643  2025-01-01      05:08      Trichy     T Nagar
# 4996    O4997       C2519  2025-11-25      02:45       Salem  Anna Nagar
# 4997    O4998       C8876  2025-08-19      03:06  Coimbatore   Velachery
# 4998    O4999       C5284  2025-03-17      22:08      Trichy     T Nagar
# 4999    O5000       C4772  2025-11-15      08:13      Trichy       Porur
#
#         Restaurant   Food_Item Category  Quantity  Price  Delivery_Time_Min  \
# 4992  SS Hyderabad     Biryani  Non-Veg         5    289                 22
# 4993       Dominos       Pizza  Non-Veg         2    367                 22
# 4994  SS Hyderabad     Parotta  Non-Veg         3    282                 44
# 4995           KFC       Meals      Veg         5    387                 59
# 4996       Dominos     Parotta      Veg         4    451                 53
# 4997       Dominos  Fried Rice      Veg         3    362                 44
# 4998  SS Hyderabad       Meals  Non-Veg         4    374                 15
# 4999  SS Hyderabad     Noodles  Non-Veg         2    280                 55
#
#      Payment_Mode  Rating
# 4992          UPI     4.4
# 4993         Card     4.7
# 4994         Card     4.2
# 4995         Card     4.8
# 4996          UPI     4.8
# 4997         Cash     4.4
# 4998          UPI     4.3
# 4999         Cash     3.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           5000 non-null   object
#  1   Customer_ID        5000 non-null   object
#  2   Order_Date         5000 non-null   object
#  3   Order_Time         5000 non-null   object
#  4   City               5000 non-null   object
#  5   Area               5000 non-null   object
#  6   Restaurant         5000 non-null   object
#  7   Food_Item          5000 non-null   object
#  8   Category           5000 non-null   object
#  9   Quantity           5000 non-null   int64
#  10  Price              5000 non-null   int64
#  11  Delivery_Time_Min  5000 non-null   int64
#  12  Payment_Mode       5000 non-null   object
#  13  Rating             5000 non-null   float64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 547.0+ KB

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Date', 'Order_Time', 'City', 'Area',
#        'Restaurant', 'Food_Item', 'Category', 'Quantity', 'Price',
#        'Delivery_Time_Min', 'Payment_Mode', 'Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Quantity        Price  Delivery_Time_Min       Rating
# count  5000.000000  5000.000000        5000.000000  5000.000000
# mean      2.985200   290.884800          37.517000     4.005200
# std       1.400348   120.544389          13.396388     0.583837
# min       1.000000    80.000000          15.000000     3.000000
# 25%       2.000000   185.750000          26.000000     3.500000
# 50%       3.000000   291.000000          37.000000     4.000000
# 75%       4.000000   395.000000          49.000000     4.500000
# max       5.000000   500.000000          60.000000     5.000000

# %%
df.isnull().sum()
# Out:
# Order_ID             0
# Customer_ID          0
# Order_Date           0
# Order_Time           0
# City                 0
# Area                 0
# Restaurant           0
# Food_Item            0
# Category             0
# Quantity             0
# Price                0
# Delivery_Time_Min    0
# Payment_Mode         0
# Rating               0
# dtype: int64

# %% [markdown]
# Total revenue

# %%
df["Revenue"] = df["Quantity"] * df["Price"]
total_revenue = df["Revenue"].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 4334086

# %% [markdown]
# Peak order times

# %%
customert_spending=df.groupby("Customer_ID")["Revenue"].sum().sort_values(ascending=False)
print(customert_spending)
# Out:
# Customer_ID
# C3487    5996
# C7759    5785
# C7706    5265
# C1763    5035
# C6261    4955
#          ...
# C4165      84
# C1626      84
# C3340      83
# C6235      82
# C2732      81
# Name: Revenue, Length: 3863, dtype: int64

# %%
df["Hour"] = pd.to_datetime(df["Order_Time"]).dt.hour
peak_hours = df["Hour"].value_counts().sort_values(ascending=False)
print(peak_hours.head())
# Out:
# Hour
# 4     237
# 9     235
# 17    227
# 14    226
# 12    220
# Name: count, dtype: int64
# /tmp/ipykernel_579/3717361710.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Hour"] = pd.to_datetime(df["Order_Time"]).dt.hour

# %% [markdown]
# Most popular Dishes

# %%
popular_dishes=df["Food_Item"].value_counts()
print(popular_dishes.head(10))
# Out:
# Food_Item
# Burger        527
# Dosa          511
# Biryani       507
# Sandwich      507
# Pizza         507
# Parotta       496
# Meals         490
# Chicken 65    489
# Noodles       487
# Fried Rice    479
# Name: count, dtype: int64

# %% [markdown]
# Food category analysis

# %%
category_anlalysis=df.groupby("Category")["Revenue"].sum()
print(category_anlalysis)
# Out:
# Category
# Non-Veg    2216799
# Veg        2117287
# Name: Revenue, dtype: int64

# %% [markdown]
# Restaurant performance

# %%
restaurant_performance=df.groupby("Restaurant")["Revenue"].sum().sort_values(ascending=False)

print(restaurant_performance)
# Out:
# Restaurant
# KFC             881939
# A2B             878264
# SS Hyderabad    875977
# Dominos         852783
# Burger King     845123
# Name: Revenue, dtype: int64

# %% [markdown]
# City-Wise Analysis

# %%
city_analysis=df.groupby("City")["Revenue"].sum().sort_values(ascending=False)
print(city_analysis)
# Out:
# City
# Trichy        905282
# Salem         889503
# Chennai       870570
# Coimbatore    847995
# Madurai       820736
# Name: Revenue, dtype: int64

# %% [markdown]
# Customer Spending Analysis

# %%
customer_spending=df.groupby("Customer_ID")["Revenue"].sum().sort_values(ascending=False)
print(customer_spending.head(10))
# Out:
# Customer_ID
# C3487    5996
# C7759    5785
# C7706    5265
# C1763    5035
# C6261    4955
# C7426    4737
# C1706    4685
# C1819    4639
# C1033    4586
# C3066    4572
# Name: Revenue, dtype: int64

# %% [markdown]
# Payment Method Analysis

# %%
payment__analysis=df["Payment_Mode"].value_counts()
print(payment__analysis)
# Out:
# Payment_Mode
# Cash    1679
# Card    1670
# UPI     1651
# Name: count, dtype: int64

# %% [markdown]
# Delivery Perfomance

# %%
avg_delivery = df["Delivery_Time_Min"].mean()
print("Average Delivery Time:",avg_delivery)
# Out:
# Average Delivery Time: 37.517

# %% [markdown]
# Customer Ratings Analysis

# %%
#Average Rating
avg_rating = df["Rating"].mean()

print("Average Rating:",round(avg_rating,2))

#Rating Distribution
rating_distribution = df["Rating"].value_counts().sort_index()

print(rating_distribution)
# Out:
# Average Rating: 4.01
# Rating
# 3.0    128
# 3.1    252
# 3.2    251
# 3.3    250
# 3.4    258
# 3.5    255
# 3.6    215
# 3.7    242
# 3.8    270
# 3.9    253
# 4.0    223
# 4.1    255
# 4.2    240
# 4.3    254
# 4.4    240
# 4.5    271
# 4.6    235
# 4.7    254
# 4.8    259
# 4.9    254
# 5.0    141
# Name: count, dtype: int64

# %% [markdown]
# Discount Analysis

# %% [markdown]
# calculate Average

# %%
df["Revenue"] = df["Quantity"] * df["Price"]
Average_Spending = df.groupby("Customer_ID")["Revenue"].sum().mean()

print("Average Spending:",round(Average_Spending,2))
# Out:
# Average Spending: 1121.95
